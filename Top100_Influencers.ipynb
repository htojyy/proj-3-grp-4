# %% [markdown]
# Navigate to directory that houses datasets. In terminal, paste the following lines to import the datasets:
# `mongoimport --db='influencers' --collection='instagram' --file=instagram_data_all-countries.csv  --drop --type=csv --headerline`
# `mongoimport --db='influencers' --collection='threads' --file=threads_data_all-countries.csv  --drop --type=csv --headerline`
# `mongoimport --db='influencers' --collection='tiktok' --file=tiktok_data_all-countries.csv  --drop --type=csv --headerline`
# `mongoimport --db='influencers' --collection='youtube' --file=youtube_data_all-countries.csv  --drop --type=csv --headerline`
#
# Install Flask-PyMongo in jupyter notebook: `!pip install Flask-PyMongo`
# Install prettytable: `!pip install -U prettytable`
# Install seaborn: `!pip install seaborn`

# %%
# !pip install Flask-PyMongo
# !pip install -U prettytable
# !pip install seaborn
# Out:
# ERROR: Could not find a version that satisfies the requirement io (from versions: none)
# ERROR: No matching distribution found for io

# %%
# pip show io
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: io

# %%
# import dependencies
from pymongo import MongoClient
import pandas as pd
import numpy as np

# %%
# connect to Mongo
client = MongoClient(port=27017)  
db = client['influencers']

# %%
collections = ['instagram', 'threads', 'youtube', 'tiktok']

# %%
for collection_name in collections:
    
    collection = db[collection_name]
    
    
    cursor = collection.find()
    df = pd.DataFrame(list(cursor))

# %%
# create pandas dataframe from collections, add column social_platform
instagram = db['instagram'].find()
instagram_df = pd.DataFrame(list(instagram))
instagram_df['social_platform'] = 'Instagram'

threads = db['threads'].find()
threads_df = pd.DataFrame(list(threads))
threads_df['social_platform'] = 'Threads'

tiktok = db['tiktok'].find()
tiktok_df = pd.DataFrame(list(tiktok))
tiktok_df['social_platform'] = 'TikTok'

youtube = db['youtube'].find()
youtube_df = pd.DataFrame(list(youtube))
youtube_df['social_platform'] = 'YouTube'

# Check dataframe
instagram_df.head()
# Out:
#                         _id  #                          NAME FOLLOWERS     ER  \
# 0  6615258d2104659b995ce9ff  1  Cristiano Ronaldo @cristiano    625.1M  0.01%
# 1  6615258d2104659b995cea00  3     Selena Gomez @selenagomez    429.7M  1.09%
# 2  6615258d2104659b995cea01  4            Kylie @kyliejenner    400.5M      -
# 3  6615258d2104659b995cea02  5       Dwayne Johnson @therock    397.8M  0.13%
# 4  6615258d2104659b995cea03  2           Leo Messi @leomessi    501.1M  0.01%
#
#          COUNTRY                                 TOPIC OF INFLUENCE  \
# 0       Portugal                                     Finance Soccer
# 1  United States  Beauty and Self Care Entertainment and Music M...
# 2  United States  Beauty and Self Care Product Showcase Modeling...
# 3  United States       Entertainment and Music Actors Public Figure
# 4      Argentina    Sports Soccer Activity General General Interest
#
#   POTENTIAL REACH social_platform
# 0          187.5M       Instagram
# ...

# %%
# union dataframes
socials_df = pd.concat([instagram_df, threads_df, tiktok_df, youtube_df], ignore_index=True)

# check merge
socials_df.head()
# Out:
#                         _id  #                          NAME FOLLOWERS     ER  \
# 0  6615258d2104659b995ce9ff  1  Cristiano Ronaldo @cristiano    625.1M  0.01%
# 1  6615258d2104659b995cea00  3     Selena Gomez @selenagomez    429.7M  1.09%
# 2  6615258d2104659b995cea01  4            Kylie @kyliejenner    400.5M      -
# 3  6615258d2104659b995cea02  5       Dwayne Johnson @therock    397.8M  0.13%
# 4  6615258d2104659b995cea03  2           Leo Messi @leomessi    501.1M  0.01%
#
#          COUNTRY                                 TOPIC OF INFLUENCE  \
# 0       Portugal                                     Finance Soccer
# 1  United States  Beauty and Self Care Entertainment and Music M...
# 2  United States  Beauty and Self Care Product Showcase Modeling...
# 3  United States       Entertainment and Music Actors Public Figure
# 4      Argentina    Sports Soccer Activity General General Interest
#
#   POTENTIAL REACH social_platform
# 0          187.5M       Instagram
# ...

# %%
# check merge
socials_df.tail()
# Out:
#                           _id    #  \
# 395  661525a2ae9afb9f5986ba10   97
# 396  661525a2ae9afb9f5986ba11   95
# 397  661525a2ae9afb9f5986ba12   98
# 398  661525a2ae9afb9f5986ba13   99
# 399  661525a2ae9afb9f5986ba14  100
#
#                                              NAME FOLLOWERS    ER  \
# 395  La Granja de Zenón @UCwpcLKMwiuPg4aqImpGk6Ew     32.3M     -
# 396            Sony PAL @UCw7xjxzbMwgBSmbeYwqYRMg     32.6M     -
# 397                   Alfredo Larin @alfredolarin     32.3M     -
# 398           Mikecrack @UCqJ5zFEED1hWs0KNQCQuYdQ     32.2M  0.6%
# 399      Saregama Music @UC_A7K2dXFsTMAciGmnNxy-Q     32.1M     -
#
#          COUNTRY TOPIC OF INFLUENCE POTENTIAL REACH social_platform
# 395    Argentina                               9.7M         YouTube
# 396                                            9.8M         YouTube
# 397  El Salvador                               9.7M         YouTube
# 398        Spain                               9.7M         YouTube
# ...

# %%
# if string contains character then create a new column
# https://stackoverflow.com/questions/59652820/create-new-column-if-dataframe-contains-specific-string
socials_df["Units_followers"] = socials_df["FOLLOWERS"].str.extract("(K|M)")[0]
socials_df.tail()
socials_df.sort_values('Units_followers', ascending=False)
# Out:
#                           _id    #                          NAME FOLLOWERS  \
# 0    6615258d2104659b995ce9ff    1  Cristiano Ronaldo @cristiano    625.1M
# 263  6615259adab61842f87f84e8   74      DonaldDucc 🦆 @donaldducc     24.7M
# 273  6615259adab61842f87f84f2   53                Camilo @camilo       28M
# 272  6615259adab61842f87f84f1   48     Michel Chavez @its.michhh     30.2M
# 271  6615259adab61842f87f84f0   57          KEEMOKAZI @keemokazi       27M
# ..                        ...  ...                           ...       ...
# 172  661525944c72517267b68aa7   73    Gary Vay-Ner-Chuk @garyvee    974.1K
# 171  661525944c72517267b68aa6   72  Nazaré Amarga @nazareamarga    975.7K
# 170  661525944c72517267b68aa5   71              Arsenal @arsenal    976.2K
# 169  661525944c72517267b68aa4   70         Sarcasm @sarcastic_us    984.8K
# 199  661525944c72517267b68ac2  100             Leo Dias @leodias    866.3K
#
# ...

# %%
# remove keep numbers only
# https://stackoverflow.com/questions/3411771/best-way-to-replace-multiple-characters-in-a-string
socials_df['followers_number'] = 0.0

for i in range(len(socials_df)):
    if socials_df["Units_followers"][i] == 'K':
        socials_df['followers_number'][i] = socials_df['FOLLOWERS'][i].replace('K', '')
    else:
        socials_df['followers_number'][i] = socials_df['FOLLOWERS'][i].replace('M', '')

# socials_df.sort_values('Units_followers')
socials_df.dtypes
# Out:
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# _id                    object
# #                       int64
# NAME                   object
# FOLLOWERS              object
# ER                     object
# COUNTRY                object
# TOPIC OF INFLUENCE     object
# POTENTIAL REACH        object
# social_platform        object
# ...

# %%
# get actual follower number
socials_df['followers_actual'] = 0.0

for i in range(len(socials_df)):
    if socials_df['Units_followers'][i] == 'M':
        socials_df['followers_actual'][i] = socials_df['followers_number'][i] * 1000000
    else:
        socials_df['followers_actual'][i] = socials_df['followers_number'][i] * 1000

# socials_df.tail(15)
socials_df.sort_values('Units_followers')
# Out:
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == "__main__":
#                           _id    #  \
# 199  661525944c72517267b68ac2  100
# 188  661525944c72517267b68ab7   90
# 187  661525944c72517267b68ab6   88
# 186  661525944c72517267b68ab5   86
# 185  661525944c72517267b68ab4   87
# ..                        ...  ...
# 119  661525944c72517267b68a72   31
# ...

# %%
# do the same extraction for Potential reach column
socials_df["Units_reach"] = socials_df["POTENTIAL REACH"].str.extract("(K|M)")[0]

socials_df['reach_number'] = 0.0

for i in range(len(socials_df)):
    if socials_df["Units_reach"][i] == 'K':
        socials_df['reach_number'][i] = socials_df['POTENTIAL REACH'][i].replace('K', '')
    else:
        socials_df['reach_number'][i] = socials_df['POTENTIAL REACH'][i].replace('M', '')

# get actual reach number
socials_df['reach_actual'] = 0.0

for i in range(len(socials_df)):
    if socials_df['Units_reach'][i] == 'M':
        socials_df['reach_actual'][i] = socials_df['reach_number'][i] * 1000000
    else:
        socials_df['reach_actual'][i] = socials_df['reach_number'][i] * 1000

socials_df.tail(15)
socials_df.sort_values('Units_reach')
# socials_df.dtypes
# Out:
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# c:\Users\olivi\anaconda3\envs\myfirstpythonenv\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
